# %%
print("bardia")
# Out:
# bardia

# %%
print("mohebi")
# Out:
# mohebi

# %%
print("11")
# Out:
# 11

# %%
print("blue")
# Out:
# blue

# %%
print("bardia")
print(12.3)
print(8)
print(True)
# Out:
# bardia
# 12.3
# 8
# True

# %%
print(type(1.05))
print(type(5.0))
print(type("true"))
print(type("5"))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'str'>

# %%
print(5+10)
# Out:
# 15

# %%
print(10-3)
# Out:
# 7

# %%
print("5"+"15")
# Out:
# 515

# %%
print("m"+"o")
# Out:
# mo

# %%
print("5"<"6")
# Out:
# True

# %%
print(5>6)
# Out:
# False

# %%
print(10/2)
# Out:
# 5.0

# %%
print(10//2)
# Out:
# 5

# %%
name="bardia"
color="blue"
food="pasta"

print(name)
print(color)
print(food)
# Out:
# bardia
# blue
# pasta

# %%
name=input("نام خود را وارد کنید")
print(name)
# Out:
# bardia

# %%
print(5*6)
# Out:
# 30
