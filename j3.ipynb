# %%
print(1)
print(2)
print(3)
print(4)
print(5)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
x =1
while x<=5:
    print(x)
    x=x+1
print("پرتاب")
# Out:
# 1
# 2
# 3
# 4
# 5
# پرتاب

# %%
password=""
while password !="1357":
    password=input("رمز را وارد کنید")
    if password == "1357":
        print("ورود موفقیت امیز بود")
    else:
        print("ورود مجاز نیست")
# Out:
# ورود مجاز نیست
# ورود مجاز نیست
# ورود موفقیت امیز بود

# %%
cardReader=100000
