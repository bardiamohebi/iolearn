# %%
name=input("نام خود را وارد کنید ")
job=input("شغل مورد علا قه ی خود را وارد کنید")
print(f"{name} عزیز شما در اینده یک {job} خواهید شد")
# Out:
# kigkg عزیز شما در اینده یک jbjk خواهید شد

# %%
number1=int(input("عدد اول را وارد کنید"))
number2=int(input("عدد دوم را وارد کنید"))
print(number1+number2)
# Out:
# 30

# %%
score=float(input("نمره ب خود را وارد کنید"))
if score>18: 
   print("باریکلا")
else:
   print("بیشتر تلاش کن")
# Out:
# بیشتر تلاش کن

# %%
pasword=int(input("رمز خودرا وارد کنید"))
if pasword==1234:
    print("در با موفقیت باز شد")
else:
    print("رمز نا درست است")
# Out:
# رمز نا درست است

# %%
light=input("رنگ چراغ را وارد کنید")
if light == "سبز":
    print("حرکت کنید")
elif light == "زرد":
    print("ارام حرکت کنید")
elif light == "قرمز":
    print("حرکت نکنید")
else:
    print("رنگ وارد شده معتبر نمیباشد")
# Out:
# رنگ وارد شده معتبر نمیباشد
